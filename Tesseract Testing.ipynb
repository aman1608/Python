# %%
import cv2
import numpy as np

image = cv2.imread(r'C:\Users\WIN8\Pictures\Scans\1.jpg')
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
sharpen_kernel = np.array([[-1,-1,-1], [-1,9,-1], [-1,-1,-1]])
sharpen = cv2.filter2D(gray, -1, sharpen_kernel)
thresh = cv2.threshold(sharpen, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)[1]

kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (3,3))
close = cv2.morphologyEx(thresh, cv2.MORPH_CLOSE, kernel, iterations=1)
result = 255 - close

cv2.imshow('sharpen', sharpen)
cv2.imshow('thresh', thresh)
cv2.imshow('close', close)
cv2.imshow('result', result)
cv2.waitKey()

# %% [markdown]
# ### Edited Image for Bad Quality images

# %%
import cv2
import numpy as np

image = cv2.imread(r'C:\Users\WIN8\Desktop\PGDS 2020\Images\1.jpeg')
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
sharpen_kernel = np.array([[-1,-1,-1], [-1,9,-1], [-1,-1,-1]])
sharpen = cv2.filter2D(gray, -1, sharpen_kernel)
thresh = cv2.threshold(sharpen, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)[1]

kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (1,1))
close = cv2.morphologyEx(thresh, cv2.MORPH_CLOSE, kernel, iterations=1)
result = 255 - close


cv2.imwrite(r'C:\Users\WIN8\Desktop\PGDS 2020\Images\test.png', result)
# Out:
# True

# %% [markdown]
# ### Original Image

# %%
img = cv2.imread(r'C:\Users\WIN8\Desktop\PGDS 2020\Images\1.jpeg')
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'
text = pytesseract.image_to_string(img)
print(text)
# Out:
# ht clarity over
# value of consid-
# vility of the levy.
# 1d consultants
# n interest waiv-
# payment of the
# ittracts interest
# nth, and penal
# ip to the value
# | levy could be
# 1 modification
# levy form, the
# PAN mandato-
# ising hardship
# S.
# it through the
# imposed 2 per
# rade and serv-
# it e-commerce
# mover of over
# g the scope of
# y. The levy only
# ivertising serv-
# 6 per cent till
# evy came into
# his year.
# uters reported
# strategic part-
# resenting US
# ie finance min-
# ax, expressing
#
#
#
#
#
# Spokesperson [Or Mat
# like to take a more pragmatic approach,
# adjusting our strategy as conditions evolve:
#
# Equity MF flows slip...
#
# Among hybrid schemes, balanced hybrid
# funds saw outflows of 21,704 crore, while
# balanced advantage fund saw outflows of
# 041 crore. Experts say balance hybrids can
# see more outflows as these were mis-sold by
# some quarters on assurance of steady
# monthly payouts through dividends.
#
# ...

# %% [markdown]
# ### Edited Image

# %%
img = cv2.imread(r'C:\Users\WIN8\Desktop\PGDS 2020\Images\test.png')
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'
text = pytesseract.image_to_string(img)
print(text)
# Out:
#
#
#
# it clarliy over “Spokesperson lor NtaLyiene.
# ralieofcorisid-:' like to. take‘a:mnore praem
# silityofthelevy, ‘adjusting ourstrategyas conditions evolve”
# \d consultants
# nintores wv, Equity MF flows slip...
# ttractsinterest Among hybrid schemes, balanced hybrid
# nth, andperial’ -funds saw outflows of &1,704 crore, while
# ip tothe value, balanced advantage find saw outflows of
# levy could'be %4Lcrore, Experts say-balance hybrids can
# r modification . se¢more. outflows as these were mis-soldby
# levy foim, the: some quarters on, assurance’ of steady
# PAN mandato- monthly payouts through dividends.
# ising hardship Thdustry éxpertssay there has.also been,
# “ amdincreased: interest in directly investing
# rt through, the {ntostocks in recent inonths, which can be
# imposed’? per seen frornthe spikein thenumber of demat
#
#
#
#
#
#
# tadeand serv- opened atseveral broking houses.
# 1He-commen;ce. frovit;liquid funds saw net
# mover of over: 6crore on the.back.of
#
# ...

# %% [markdown]
# # Full Page Image

# %%
# Editing
import cv2
import numpy as np

image = cv2.imread(r'C:\Users\WIN8\Desktop\PGDS 2020\Images\4.jpeg')
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
sharpen_kernel = np.array([[-1,-1,-1], [-1,9,-1], [-1,-1,-1]])
sharpen = cv2.filter2D(gray, -1, sharpen_kernel)
thresh = cv2.threshold(sharpen, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)[1]

kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (1,1))
close = cv2.morphologyEx(thresh, cv2.MORPH_CLOSE, kernel, iterations=1)
result = 255 - close


cv2.imwrite(r'C:\Users\WIN8\Desktop\PGDS 2020\Images\test.png', result)
# Out:
# True

# %% [markdown]
# ### Original

# %%
img = cv2.imread(r'C:\Users\WIN8\Desktop\PGDS 2020\Images\4.jpeg')
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'
text = pytesseract.image_to_string(img)
print(text)
# Out:
# I paler
# SC grants bail to Unitech
# promoter Sanjay Chandra
#
# === Zara founderlifts veilon
#
# = his $17-bn realty empire
#
# SoftBank stock
# back to dotcom
# bubble erahigh
#
#
#
# ke ee ew
#
# Hiranandani 's data hub ‘Bomb
# to ra digital economy 2
#
# Soe n-th sale dita cetnutn meron

# %% [markdown]
# ### Edited

# %%
img = cv2.imread(r'C:\Users\WIN8\Desktop\PGDS 2020\Images\test.png')
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'
text = pytesseract.image_to_string(img)
print(text)
# Out:
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ET bere Sige Trane See ae
# 7 * ia Le tet eS
#
#
#
# Hiranandani'sdata hub “Bont
# ‘to tap digital econo
#
# pa hyp santa ut ae
#
#
#
#
#
# ssi
#
# Me a |
# a ‘Capgemini 6ffars hikes, promotions
#
# dra aha ier 2 i
#
# gecmmeein [ou ea Me rode iif
# Wsnctoceer cei te ae
# a : 1 Reena isle. his .
# ie aes! faslunions ata Nei
#
#
#
#
#
#
#
#
#
# cotton wi
# |; eucauenlones
# abla bet
#
#
#
#
#
#
# Se Rie cioeeae
# Soi Sune
#
#
#
#
#
#
#
# Gite
#
# ieee
#
# Gate cceetiers Wee
# mr Sees, ea
#
#
#
#
#
# ae
# coors
#
#
#
#
#
#
#
#
#
#
#
#
# poe
# eee
#
# seas
# a
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ee ee
# ernie
# eo nein a
# eee a ieee
# oe Be SENS cre
#
#
#
#
#
#
#
#
#
#
# dla ninyiebtiesln ase
